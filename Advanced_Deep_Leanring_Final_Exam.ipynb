# %% [markdown]
# <a href="https://colab.research.google.com/github/sonjoy1s/NLP/blob/main/Advanced_Deep_Leanring_Final_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NLP Exam
#  Notebook
#
# Fill in the blanks to complete each coding task. <br>
# Each question have 5 marks.

# %% [markdown]
# ## Q1: One-Hot Encoding

# %%
from sklearn.preprocessing import OneHotEncoder

words = [["cat"], ["dog"], ["bird"], ["cat"]]

encoder = OneHotEncoder()

encoded = encoder.fit_transform(words)

print(encoded.toarray())
# Out:
# [[0. 1. 0.]
#  [0. 0. 1.]
#  [1. 0. 0.]
#  [0. 1. 0.]]

# %% [markdown]
# ## Q2: TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = [
    "I love NLP",
    "NLP is amazing",
    "Machine learning is fun"
]

vectorizer = TfidfVectorizer()

tfidf_matrix = vectorizer.fit_transform(documents)

print(tfidf_matrix.toarray())
# Out:
# [[0.         0.         0.         0.         0.79596054 0.
#   0.60534851]
#  [0.68091856 0.         0.51785612 0.         0.         0.
#   0.51785612]
#  [0.         0.52863461 0.40204024 0.52863461 0.         0.52863461
#   0.        ]]

# %% [markdown]
# ## Q3: CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

docs = ["apple orange apple","orange banana"]

vectorizer = CountVectorizer()

matrix = vectorizer.fit_transform(docs)

print(matrix.toarray())
# Out:
# [[2 0 1]
#  [0 1 1]]

# %% [markdown]
# ## Q4: Word2Vec

# %%
# !pip install gensim
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.6.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.2.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 62.6 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
# !pip install wget
# Out:
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=970797788fdfb7b886700eb8f06924a570da4c5a2fa8b5c44f240e8128b301ad
#   Stored in directory: /root/.cache/pip/wheels/01/46/3b/e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
from gensim.models import Word2Vec

sentences = [
    ["I","love","NLP"],
    ["NLP","is","awesome"],
    ["Machine","learning","is","fun"]
]

model = Word2Vec(
    sentences,
    vector_size=50, # i'm used to vector size = 50 but can write 100 or 200.... but it's small data so size 50 good
    window=5,
    min_count=1
)

print(model.wv["NLP","is"])
# Out:
# [[-1.63158346e-02  8.99159629e-03 -8.27415194e-03  1.64907216e-03
#    1.69972405e-02 -8.92435294e-03  9.03500058e-03 -1.35739204e-02
#   -7.09697744e-03  1.87970158e-02 -3.15530528e-03  6.42743136e-04
#   -8.28125980e-03 -1.53653761e-02 -3.01601645e-03  4.93958965e-03
#   -1.77605392e-03  1.10673234e-02 -5.48595423e-03  4.52013034e-03
#    1.09115886e-02  1.66919064e-02 -2.90748128e-03 -1.84162855e-02
#    8.74110498e-03  1.14356994e-03  1.48838162e-02 -1.62656547e-03
#   -5.27682761e-03 -1.75060183e-02 -1.71311374e-03  5.65312617e-03
#    1.08028576e-02  1.41053125e-02 -1.14062428e-02  3.71763948e-03
#    1.21777272e-02 -9.59610194e-03 -6.21452089e-03  1.35952588e-02
#    3.26295127e-03  3.79834179e-04  6.94727432e-03  4.35554975e-04
#    1.92376524e-02  1.01212077e-02 -1.78347807e-02 -1.40831210e-02
#    1.80291175e-03  1.27850678e-02]
#  [-1.07245450e-03  4.72862710e-04  1.02066994e-02  1.80185456e-02
#   -1.86058991e-02 -1.42336180e-02  1.29177449e-02  1.79459769e-02
#   -1.00308564e-02 -7.52674323e-03  1.47610093e-02 -3.06694279e-03
#   -9.07322671e-03  1.31081035e-02 -9.72032081e-03 -3.63203534e-03
#    5.75315952e-03  1.98374758e-03 -1.65704302e-02 -1.88976359e-02
#    1.46235321e-02  1.01405242e-02  1.35153867e-02  1.52573106e-03
#    1.27017805e-02 -6.81073172e-03 -1.89280277e-03  1.15371468e-02
#   -1.50432754e-02 -7.87220709e-03 -1.50231645e-02 -1.86008448e-03
#    1.90762375e-02 -1.46383336e-02 -4.66753729e-03 -3.87548213e-03
#    1.61548741e-02 -1.18617918e-02  9.03248801e-05 -9.50746797e-03
#   -1.92071013e-02  1.00145862e-02 -1.75191704e-02 -8.78365058e-03
#   -7.01999670e-05 -5.92362892e-04 -1.53224804e-02  1.92294866e-02
#    9.96411592e-03  1.84662864e-02]]

# %% [markdown]
# ## Q5: Lowercase

# %%
text = "WELCOME TO NLP"

text = text.lower()

print(text)
# Out:
# welcome to nlp

# %% [markdown]
# ## Q6: Remove Punctuation

# %%
import re

text = "Hello!!! Welcome, to NLP."

clean_text = re.sub(r'[^\w\s]','',text)

print(clean_text)
# Out:
# Hello Welcome to NLP

# %% [markdown]
# ## Q7: Remove Numbers

# %%
import re

text = "Python3 was released in 2008."

result = re.sub(r'\d+','',text)

print(result)
# Out:
# Python was released in .

# %% [markdown]
# ## Q8: Extract Email

# %%
import re

text = """
Contact:
student@gmail.com
teacher@yahoo.com
"""

emails = re.findall(r"[\w\.-]+@[\w\.-]+\.\w+",text)

print(emails)
# Out:
# ['student@gmail.com', 'teacher@yahoo.com']

# %% [markdown]
# ## Q9: Remove Extra Spaces

# %%
import re

text = "I      love       NLP"

text = re.sub(r"\s+"," ",text)

print(text)
# Out:
# I love NLP

# %% [markdown]
# ## Q10: Tokenization

# %%
text = "Natural Language Processing"

tokens = text.split()

print(tokens)
# Out:
# ['Natural', 'Language', 'Processing']

# %%
# !pip install nltk
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.3)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
text = "Natural Language Processing"

tokens = word_tokenize(text)

print(tokens) # Tokenization from import kore
# Out:
# ['Natural', 'Language', 'Processing']

# %% [markdown]
# ## Q11: Stopword Removal

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

words = ["I", "love", "to", "learn", "NLP"]

stop_words = set(stopwords.words("english"))

filtered = [word for word in words if word.lower() not in stop_words]

print(filtered)
# Out:
# ['love', 'learn', 'NLP']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## Q12: Stemming

# %%
from nltk.stem import PorterStemmer
#nltk.download('porter')
stemmer = PorterStemmer()

words = ["playing", "played", "plays"]

stems = [stemmer.stem(word) for word in words] # used to stem function

print(stems)
# Out:
# ['play', 'play', 'play']

# %% [markdown]
# ## Q13: Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()

words = ["running", "better", "cars"]

lemmas = [lemmatizer.lemmatize(word) for word in words]

print(lemmas)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# ['running', 'better', 'car']

# %% [markdown]
# ## Q14: Remove URLs

# %%
import re

text = "Visit https://google.com for more information."

clean = re.sub(r"https?://\S+\s+","", text

)

print(clean.lower())
# Out:
# visit for more information.

# %% [markdown]
# ## Q15: Remove HTML

# %%
import re

html = "<h1>Welcome</h1><p>This is NLP.</p>"

#write rest of the code
cleans = re.sub(r"<.*?>", " ", html)
clean = re.sub(r"\s+", " ", cleans)
print(clean.lower())
# Out:
#  welcome this is nlp.

# %% [markdown]
# ## Q16: Bag of Words

# %%
from sklearn.feature_extraction.text import CountVectorizer

corpus = [
    "I love NLP",
    "NLP is fun"
]

#apply bag of words
vectorizer = CountVectorizer()
bag_of_words = vectorizer.fit_transform(corpus)

print(bag_of_words.toarray())
# Out:
# [[0 0 1 1]
#  [1 1 0 1]]

# %% [markdown]
# ## Q17: Access Word2Vec Vector

# %%
from gensim.models import Word2Vec

sentences = [
    ["cat","dog","animal"],
    ["lion","tiger","animal"]
]

model = Word2Vec(sentences, vector_size=50, min_count=1)

vector = model.wv["cat","animal"]

print(vector)
# Out:
# [[ 1.89127924e-04  6.15463965e-03 -1.36252902e-02 -2.75093084e-03
#    1.53371617e-02  1.46928187e-02 -7.34659424e-03  5.28540369e-03
#   -1.66342594e-02  1.24109723e-02 -9.27464478e-03 -6.32821303e-03
#    1.86227132e-02  1.74677139e-03  1.49814058e-02 -1.21481251e-02
#    1.03210136e-02  1.98456459e-02 -1.69147830e-02 -1.02713825e-02
#   -1.41296741e-02 -9.72530339e-03 -7.55712762e-03 -1.70723982e-02
#    1.59112122e-02 -9.68787633e-03  1.68472268e-02  1.05251409e-02
#   -1.31000523e-02  7.91574270e-03  1.09402994e-02 -1.48530724e-02
#   -1.48114394e-02 -4.95046144e-03 -1.72514506e-02 -3.16314469e-03
#   -8.06865690e-04  6.59936899e-03  2.88376096e-03 -1.76284311e-03
#   -1.11881159e-02  3.46073159e-03 -1.79474358e-03  1.35873817e-02
#    7.94718042e-03  9.05894302e-03  2.86861183e-03 -5.39971096e-03
#   -8.73362552e-03 -2.06414936e-03]
#  [-1.07245450e-03  4.72862710e-04  1.02066994e-02  1.80185456e-02
#   -1.86058991e-02 -1.42336180e-02  1.29177449e-02  1.79459769e-02
#   -1.00308564e-02 -7.52674323e-03  1.47610093e-02 -3.06694279e-03
#   -9.07322671e-03  1.31081035e-02 -9.72032081e-03 -3.63203534e-03
#    5.75315952e-03  1.98374758e-03 -1.65704302e-02 -1.88976359e-02
#    1.46235321e-02  1.01405242e-02  1.35153867e-02  1.52573106e-03
#    1.27017805e-02 -6.81073172e-03 -1.89280277e-03  1.15371468e-02
#   -1.50432754e-02 -7.87220709e-03 -1.50231645e-02 -1.86008448e-03
#    1.90762375e-02 -1.46383336e-02 -4.66753729e-03 -3.87548213e-03
#    1.61548741e-02 -1.18617918e-02  9.03248801e-05 -9.50746797e-03
#   -1.92071013e-02  1.00145862e-02 -1.75191704e-02 -8.78365058e-03
#   -7.01999670e-05 -5.92362892e-04 -1.53224804e-02  1.92294866e-02
#    9.96411592e-03  1.84662864e-02]]

# %% [markdown]
# ## Q18: Regex Phone

# %%
import re

text = "Call me at +8801712345678"

phone = re.findall(
    r"\+\d{13}", text)

print(phone)
# Out:
# ['+8801712345678']

# %% [markdown]
# ## Q19: Remove Special Characters

# %%
import re

text = "Hello@#$%^World!"

clean = re.sub(
    r"[^A-Za-z0-9\s]",
    " ",
    text
)

print(clean)

cleans = re.sub(r"\s+"," ",clean) # for used simple space word and this is extra line(code)

print(cleans) #(Extra code)
# Out:
# Hello     World
# Hello World

# %% [markdown]
# ## Q20: Complete NLP Preprocessing

# %%
import re

text = "Hello!!! Visit https://abc.com Email: student@gmail.com 123"

text = text.lower()

text = re.sub(r"https?://\S+", "", text)
text = re.sub(r"\S+@\S+", "", text)
text = re.sub(r"\d+", "", text)
text = re.sub(r"[^\w\s]", "", text)
text = re.sub(r"\s+", " ", text).strip()

print(text)

#extra code
tokenized = text.split()
print(tokenized)
# Out:
# hello visit email
# ['hello', 'visit', 'email']

# %% [markdown]
# #Q: Optional :
#
# **Word2Vec**
#
# Explain the difference between **CBOW (Continuous Bag of Words)** and **Skip-Gram** architectures.
#
# Your answer should include:
# 1. How each model predicts words.
# 2. Which model performs better on small datasets.
# 3. Which model is better for learning rare words.
# 4. One practical advantage of Word2Vec over One-Hot Encoding.
